# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("bilgisayar_data_islenmis3.csv")
df=pd.DataFrame()

# %%
data.tail()
# Out:
#                     Ekran Kartı Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240                  NaN           Harici
# 597     Nvidia GeForce RTX 4070                  NaN           Harici
# 598  Nvidia GeForce RTX 4070 Ti                  12            Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#      Garanti Süresi                 Garanti Tipi  Ram (Sistem Belleği)  \
# 595             2.0  Resmi Distribütör Garantili                   8.0
# 596             2.0  Resmi Distribütör Garantili                  16.0
# 597             2.0  Resmi Distribütör Garantili                  32.0
# 598             2.0     Zeiron Türkiye Garantili                  16.0
# 599             2.0      Apple Türkiye Garantili                  64.0
#
#      SSD Kapasitesi   İşlemci Tipi  İşlemci Çekirdek Sayısı     price
# ...

# %%
data["Ekran Kartı"].value_counts()
# Out:
# Ekran Kartı
# Nvidia GeForce RTX 4060          50
# Nvidia GeForce RTX 3050          49
# Intel UHD Graphics               41
# Nvidia GeForce RTX 4050          39
# Intel Iris Graphics              38
# Dahili Ekran Kartı               37
# AMD Radeon Graphics              27
# Nvidia GeForce RTX3060           19
# Nvidia GeForce RTX 4070          19
# Nvidia GeForce RTX 3050 Ti       17
# AMD Radeon RX 580                15
# Intel HD Graphics                13
# Intel UHD Graphics 600           12
# Nvidia GeForce RTX 2050          11
# Nvidia GeForce RTX 4090          10
# M3                               10
# AMD Radeon RX 550                 8
# Intel XE Graphics                 7
# Belirtilmemiş                     7
# Nvidia Geforce GT 740             6
# Nvidia GeForce RTX 2060 Super     6
# Nvidia GeForce MX450              6
# AMD                               5
# Nvidia GeForce RTX 4060Ti         4
# Nvidia GeForce GT 730             4
# ...

# %%
# !pip install scikit-learn

# %%
data.tail()
# Out:
#                     Ekran Kartı Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240                  NaN           Harici
# 597     Nvidia GeForce RTX 4070                  NaN           Harici
# 598  Nvidia GeForce RTX 4070 Ti                  12            Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#      Garanti Süresi                 Garanti Tipi  Ram (Sistem Belleği)  \
# 595             2.0  Resmi Distribütör Garantili                   8.0
# 596             2.0  Resmi Distribütör Garantili                  16.0
# 597             2.0  Resmi Distribütör Garantili                  32.0
# 598             2.0     Zeiron Türkiye Garantili                  16.0
# 599             2.0      Apple Türkiye Garantili                  64.0
#
#      SSD Kapasitesi   İşlemci Tipi  İşlemci Çekirdek Sayısı     price
# ...

# %%
df["Ekran_Karti"] = data["Ekran Kartı"]
df["Ekran_Karti_Hafizasi"] = data["Ekran Kartı Hafızası"]
df["Ekran_Karti_Tipi"] = data["Ekran Kartı Tipi"]
df["Garanti_Suresi"] = data["Garanti Süresi"]
df["Garanti_Tipi"] = data["Garanti Tipi"]
df["Ram"] = data["Ram (Sistem Belleği)"]
df["SSD_Kapasitesi"] = data["SSD Kapasitesi"]
df["Islemci_Tipi"] = data["İşlemci Tipi"]
df["Islemci_Cekirdek_Sayisi"] = data["İşlemci Çekirdek Sayısı"]
df["Fiyat"] = data["price"]

# %%
df.head()
# Out:
#            Ekran_Karti Ekran_Karti_Hafizasi Ekran_Karti_Tipi  Garanti_Suresi  \
# 0   Dahili Ekran Kartı           Paylaşımlı           Dahili             2.0
# 1  AMD Radeon Graphics           Paylaşımlı           Dahili             2.0
# 2                  NaN                  NaN              NaN             NaN
# 3    AMD Radeon RX 550                   4            Harici             2.0
# 4   Dahili Ekran Kartı           Paylaşımlı           Dahili             2.0
#
#                   Garanti_Tipi   Ram  SSD_Kapasitesi   Islemci_Tipi  \
# 0  Resmi Distribütör Garantili   8.0           256.0  Intel Core i5
# 1     Lenovo Türkiye Garantili  16.0           512.0    AMD Ryzen 7
# 2                          NaN   NaN             NaN            NaN
# 3  Resmi Distribütör Garantili  32.0           256.0     Intel Xeon
# 4     Lenovo Türkiye Garantili   4.0             NaN  Intel Celeron
#
#    Islemci_Cekirdek_Sayisi   Fiyat
# 0                      4.0  10.499
# ...

# %%
df.tail()
# Out:
#                     Ekran_Karti Ekran_Karti_Hafizasi Ekran_Karti_Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240                  NaN           Harici
# 597     Nvidia GeForce RTX 4070                  NaN           Harici
# 598  Nvidia GeForce RTX 4070 Ti                  12            Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#      Garanti_Suresi                 Garanti_Tipi   Ram  SSD_Kapasitesi  \
# 595             2.0  Resmi Distribütör Garantili   8.0           256.0
# 596             2.0  Resmi Distribütör Garantili  16.0           256.0
# 597             2.0  Resmi Distribütör Garantili  32.0           512.0
# 598             2.0     Zeiron Türkiye Garantili  16.0          1000.0
# 599             2.0      Apple Türkiye Garantili  64.0          1000.0
#
#       Islemci_Tipi  Islemci_Cekirdek_Sayisi     Fiyat
# 595    AMD Ryzen 5                      4.0   10.4990
# ...

# %%
df["Ekran_Karti"].value_counts()
# Out:
# Ekran_Karti
# Nvidia GeForce RTX 4060          50
# Nvidia GeForce RTX 3050          49
# Intel UHD Graphics               41
# Nvidia GeForce RTX 4050          39
# Intel Iris Graphics              38
# Dahili Ekran Kartı               37
# AMD Radeon Graphics              27
# Nvidia GeForce RTX3060           19
# Nvidia GeForce RTX 4070          19
# Nvidia GeForce RTX 3050 Ti       17
# AMD Radeon RX 580                15
# Intel HD Graphics                13
# Intel UHD Graphics 600           12
# Nvidia GeForce RTX 2050          11
# Nvidia GeForce RTX 4090          10
# M3                               10
# AMD Radeon RX 550                 8
# Intel XE Graphics                 7
# Belirtilmemiş                     7
# Nvidia Geforce GT 740             6
# Nvidia GeForce RTX 2060 Super     6
# Nvidia GeForce MX450              6
# AMD                               5
# Nvidia GeForce RTX 4060Ti         4
# Nvidia GeForce GT 730             4
# ...

# %%
df["Ekran_Karti_Hafizasi"].value_counts()
# Out:
# Ekran_Karti_Hafizasi
# Paylaşımlı    185
# 4             102
# 8             101
# 6              63
# 2              15
# 16             13
# 12              7
# 1               3
# Name: count, dtype: int64

# %%
df["Ekran_Karti_Tipi"].value_counts()
# Out:
# Ekran_Karti_Tipi
# Harici                    298
# Dahili                    211
# Paylaşımlı                 10
# Nvidia Quadro P2000         1
# Nvidia GeForce RTX3060      1
# AMD Radeon RX5600M          1
# Name: count, dtype: int64

# %%
df["Garanti_Suresi"].value_counts()
# Out:
# Garanti_Suresi
# 2.0    500
# 3.0      9
# Name: count, dtype: int64

# %%
df["Garanti_Tipi"].value_counts()
# Out:
# Garanti_Tipi
# Resmi Distribütör Garantili      197
# Asus Türkiye Garantili            57
# Lenovo Türkiye Garantili          52
# Casper Türkiye Garantili          35
# HP Türkiye Garantili              32
# ACER Türkiye Garantili            30
# Apple Türkiye Garantili           28
# Monster Türkiye Garantili         23
# İthalatçı Garantili               23
# MSI Türkiye Garantili             22
# Resmi DistribÃ¼tÃ¶r Garantili     11
# Dell Türkiye Garantili             9
# Huawei Türkiye Garantili           7
# İzoly Türkiye Garantisi            6
# Asus TÃ¼rkiye Garantili            5
# Zeiron Türkiye Garantili           4
# Apple TÃ¼rkiye Garantili           2
# Lenovo TÃ¼rkiye Garantili          2
# Samsung TR Garantili               1
# Casper TÃ¼rkiye Garantili          1
# MSI TÃ¼rkiye Garantili             1
# Zeiron TÃ¼rkiye Garantili          1
# HP TÃ¼rkiye Garantili              1
# Monster TÃ¼rkiye Garantili         1
# Name: count, dtype: int64

# %%
df["Ram"].value_counts()
# Out:
# Ram
# 16.0     250
# 8.0      144
# 32.0      68
# 4.0       28
# 64.0      16
# 128.0      7
# 18.0       3
# 36.0       3
# 12.0       2
# 48.0       2
# 24.0       2
# 1.0        1
# Name: count, dtype: int64

# %%
df["SSD_Kapasitesi"].value_counts()
# Out:
# SSD_Kapasitesi
# 512.0     219
# 1000.0    142
# 256.0     104
# 128.0      19
# 500.0      19
# 2000.0     13
# 240.0       7
# 4000.0      5
# 120.0       5
# 32.0        2
# 480.0       2
# 8.0         1
# 64.0        1
# Name: count, dtype: int64

# %%
df["Islemci_Tipi"].value_counts()
# Out:
# Islemci_Tipi
# Intel Core i5       194
# Intel Core i7       104
# AMD Ryzen 5          47
# AMD Ryzen 7          41
# Intel Core i3        30
# Intel Core i9        26
# Intel Celeron        25
# M3                   10
# Intel Xeon            9
# Apple M1              7
# M2                    6
# Apple M2              5
# AMD Ryzen 3           5
# AMD Athlon            4
# MediaTek P60T         3
# AMD Ryzen 9           2
# Apple M1 Pro          1
# Intel Atom            1
# AMD E                 1
# Intel Core M          1
# AMD A6                1
# Ryzen Z1 Extreme      1
# Apple M2 Pro          1
# AMD                   1
# Name: count, dtype: int64

# %%
df["Islemci_Cekirdek_Sayisi"].value_counts()
# Out:
# Islemci_Cekirdek_Sayisi
# 8.0     116
# 4.0     101
# 6.0      74
# 10.0     57
# 12.0     40
# 14.0     37
# 2.0      36
# 24.0     21
# 16.0     16
# 1.0       5
# 20.0      3
# 18.0      1
# Name: count, dtype: int64

# %%
df = df.drop(2)

# %%
df.head()
# Out:
#            Ekran_Karti Ekran_Karti_Hafizasi Ekran_Karti_Tipi  Garanti_Suresi  \
# 0   Dahili Ekran Kartı           Paylaşımlı           Dahili             2.0
# 1  AMD Radeon Graphics           Paylaşımlı           Dahili             2.0
# 3    AMD Radeon RX 550                   4            Harici             2.0
# 4   Dahili Ekran Kartı           Paylaşımlı           Dahili             2.0
# 5  AMD Radeon Graphics           Paylaşımlı           Dahili             2.0
#
#                   Garanti_Tipi   Ram  SSD_Kapasitesi   Islemci_Tipi  \
# 0  Resmi Distribütör Garantili   8.0           256.0  Intel Core i5
# 1     Lenovo Türkiye Garantili  16.0           512.0    AMD Ryzen 7
# 3  Resmi Distribütör Garantili  32.0           256.0     Intel Xeon
# 4     Lenovo Türkiye Garantili   4.0             NaN  Intel Celeron
# 5  Resmi Distribütör Garantili   8.0           256.0     AMD Athlon
#
#    Islemci_Cekirdek_Sayisi   Fiyat
# 0                      4.0  10.499
# ...

# %%
print(df["Ekran_Karti"].isnull().values.any())
print(df["Ekran_Karti_Hafizasi"].isnull().values.any())
print(df["Ekran_Karti_Tipi"].isnull().values.any())
print(df["Garanti_Suresi"].isnull().values.any())
print(df["Garanti_Tipi"].isnull().values.any())
print(df["Ram"].isnull().values.any())
print(df["SSD_Kapasitesi"].isnull().values.any())
print(df["Islemci_Tipi"].isnull().values.any())
print(df["Islemci_Cekirdek_Sayisi"].isnull().values.any())
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
df.Ekran_Karti.fillna("Nvidia GeForce RTX 4060",inplace=True)
df.Ekran_Karti_Hafizasi.fillna("Paylaşımlı" ,inplace=True)
df.Ekran_Karti_Tipi.fillna("Harici",inplace=True)
df.Garanti_Suresi.fillna(2,inplace=True)
df.Garanti_Tipi.fillna("Resmi Distribütör Garantili",inplace=True)
df.Ram.fillna(16,inplace=True)
df.SSD_Kapasitesi.fillna(512,inplace=True)
df.Islemci_Tipi.fillna("Intel Core i5",inplace=True)
df.Islemci_Cekirdek_Sayisi.fillna(8,inplace=True)

# %%
print(df["Ekran_Karti"].isnull().values.any())
print(df["Ekran_Karti_Hafizasi"].isnull().values.any())
print(df["Ekran_Karti_Tipi"].isnull().values.any())
print(df["Garanti_Suresi"].isnull().values.any())
print(df["Garanti_Tipi"].isnull().values.any())
print(df["Ram"].isnull().values.any())
print(df["SSD_Kapasitesi"].isnull().values.any())
print(df["Islemci_Tipi"].isnull().values.any())
print(df["Islemci_Cekirdek_Sayisi"].isnull().values.any())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
df.head()
# Out:
#            Ekran_Karti Ekran_Karti_Hafizasi Ekran_Karti_Tipi  Garanti_Suresi  \
# 0   Dahili Ekran Kartı           Paylaşımlı           Dahili             2.0
# 1  AMD Radeon Graphics           Paylaşımlı           Dahili             2.0
# 3    AMD Radeon RX 550                   4            Harici             2.0
# 4   Dahili Ekran Kartı           Paylaşımlı           Dahili             2.0
# 5  AMD Radeon Graphics           Paylaşımlı           Dahili             2.0
#
#                   Garanti_Tipi   Ram  SSD_Kapasitesi   Islemci_Tipi  \
# 0  Resmi Distribütör Garantili   8.0           256.0  Intel Core i5
# 1     Lenovo Türkiye Garantili  16.0           512.0    AMD Ryzen 7
# 3  Resmi Distribütör Garantili  32.0           256.0     Intel Xeon
# 4     Lenovo Türkiye Garantili   4.0           512.0  Intel Celeron
# 5  Resmi Distribütör Garantili   8.0           256.0     AMD Athlon
#
#    Islemci_Cekirdek_Sayisi   Fiyat
# 0                      4.0  10.499
# ...

# %%
df.tail()
# Out:
#                     Ekran_Karti Ekran_Karti_Hafizasi Ekran_Karti_Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240           Paylaşımlı           Harici
# 597     Nvidia GeForce RTX 4070           Paylaşımlı           Harici
# 598  Nvidia GeForce RTX 4070 Ti                  12            Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#      Garanti_Suresi                 Garanti_Tipi   Ram  SSD_Kapasitesi  \
# 595             2.0  Resmi Distribütör Garantili   8.0           256.0
# 596             2.0  Resmi Distribütör Garantili  16.0           256.0
# 597             2.0  Resmi Distribütör Garantili  32.0           512.0
# 598             2.0     Zeiron Türkiye Garantili  16.0          1000.0
# 599             2.0      Apple Türkiye Garantili  64.0          1000.0
#
#       Islemci_Tipi  Islemci_Cekirdek_Sayisi     Fiyat
# 595    AMD Ryzen 5                      4.0   10.4990
# ...

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
df["Ekran_Karti"].value_counts()
# Out:
# Ekran_Karti
# Nvidia GeForce RTX 4060          123
# Nvidia GeForce RTX 3050           49
# Intel UHD Graphics                41
# Nvidia GeForce RTX 4050           39
# Intel Iris Graphics               38
# Dahili Ekran Kartı                37
# AMD Radeon Graphics               27
# Nvidia GeForce RTX3060            19
# Nvidia GeForce RTX 4070           19
# Nvidia GeForce RTX 3050 Ti        17
# AMD Radeon RX 580                 15
# Intel HD Graphics                 13
# Intel UHD Graphics 600            12
# Nvidia GeForce RTX 2050           11
# Nvidia GeForce RTX 4090           10
# M3                                10
# AMD Radeon RX 550                  8
# Intel XE Graphics                  7
# Belirtilmemiş                      7
# Nvidia Geforce GT 740              6
# Nvidia GeForce RTX 2060 Super      6
# Nvidia GeForce MX450               6
# AMD                                5
# Nvidia GeForce RTX 4060Ti          4
# Nvidia GeForce GT 730              4
# ...

# %%
df["Ekran_Karti"] = enc.fit_transform(df['Ekran_Karti'])

# %%
df["Ekran_Karti"].value_counts()
# Out:
# Ekran_Karti
# 47    123
# 40     49
# 20     41
# 46     39
# 18     38
# 14     37
# 2      27
# 53     19
# 49     19
# 41     17
# 9      15
# 15     13
# 21     12
# 37     11
# 52     10
# 28     10
# 7       8
# 23      7
# 13      7
# 54      6
# 39      6
# 36      6
# 0       5
# 48      4
# 30      4
# 35      4
# 26      4
# 31      4
# 6       4
# 32      3
# 38      3
# 51      3
# 25      3
# 29      3
# 42      3
# 1       2
# 33      2
# 11      2
# 50      2
# 10      2
# 56      2
# 57      2
# 58      2
# 44      1
# 19      1
# 16      1
# 4       1
# 34      1
# 22      1
# 5       1
# 27      1
# 3       1
# 43      1
# 24      1
# 55      1
# 8       1
# 17      1
# 45      1
# 12      1
# Name: count, dtype: int64

# %%
df["Ekran_Karti_Hafizasi"].value_counts()
# Out:
# Ekran_Karti_Hafizasi
# Paylaşımlı    295
# 4             102
# 8             101
# 6              63
# 2              15
# 16             13
# 12              7
# 1               3
# Name: count, dtype: int64

# %%
df["Ekran_Karti_Hafizasi"] = enc.fit_transform(df['Ekran_Karti_Hafizasi'])

# %%
df["Ekran_Karti_Hafizasi"].value_counts()
# Out:
# Ekran_Karti_Hafizasi
# 7    295
# 4    102
# 6    101
# 5     63
# 3     15
# 2     13
# 1      7
# 0      3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Ekran_Karti  Ekran_Karti_Hafizasi Ekran_Karti_Tipi  Garanti_Suresi  \
# 0           14                     7           Dahili             2.0
# 1            2                     7           Dahili             2.0
# 3            7                     4           Harici             2.0
# 4           14                     7           Dahili             2.0
# 5            2                     7           Dahili             2.0
#
#                   Garanti_Tipi   Ram  SSD_Kapasitesi   Islemci_Tipi  \
# 0  Resmi Distribütör Garantili   8.0           256.0  Intel Core i5
# 1     Lenovo Türkiye Garantili  16.0           512.0    AMD Ryzen 7
# 3  Resmi Distribütör Garantili  32.0           256.0     Intel Xeon
# 4     Lenovo Türkiye Garantili   4.0           512.0  Intel Celeron
# 5  Resmi Distribütör Garantili   8.0           256.0     AMD Athlon
#
#    Islemci_Cekirdek_Sayisi   Fiyat
# 0                      4.0  10.499
# 1                      8.0  13.999
# ...

# %%
df["Ekran_Karti_Tipi"].value_counts()
# Out:
# Ekran_Karti_Tipi
# Harici                    375
# Dahili                    211
# Paylaşımlı                 10
# Nvidia Quadro P2000         1
# Nvidia GeForce RTX3060      1
# AMD Radeon RX5600M          1
# Name: count, dtype: int64

# %%
df["Ekran_Karti_Tipi"] = enc.fit_transform(df['Ekran_Karti_Tipi'])

# %%
df["Ekran_Karti_Tipi"].value_counts()
# Out:
# Ekran_Karti_Tipi
# 2    375
# 1    211
# 5     10
# 4      1
# 3      1
# 0      1
# Name: count, dtype: int64

# %%
df["Garanti_Suresi"].value_counts()
# Out:
# Garanti_Suresi
# 2.0    590
# 3.0      9
# Name: count, dtype: int64

# %%
df["Garanti_Suresi"].value_counts()
# Out:
# Garanti_Suresi
# 2.0    590
# 3.0      9
# Name: count, dtype: int64

# %%
df["Garanti_Tipi"].value_counts()
# Out:
# Garanti_Tipi
# Resmi Distribütör Garantili      245
# Asus Türkiye Garantili            57
# Lenovo Türkiye Garantili          52
# Casper Türkiye Garantili          35
# HP Türkiye Garantili              32
# ACER Türkiye Garantili            30
# Apple Türkiye Garantili           28
# Monster Türkiye Garantili         23
# İthalatçı Garantili               23
# MSI Türkiye Garantili             22
# Resmi DistribÃ¼tÃ¶r Garantili     11
# Dell Türkiye Garantili             9
# Huawei Türkiye Garantili           7
# İzoly Türkiye Garantisi            6
# Asus TÃ¼rkiye Garantili            5
# Zeiron Türkiye Garantili           4
# Apple TÃ¼rkiye Garantili           2
# Lenovo TÃ¼rkiye Garantili          2
# Samsung TR Garantili               1
# Casper TÃ¼rkiye Garantili          1
# MSI TÃ¼rkiye Garantili             1
# Zeiron TÃ¼rkiye Garantili          1
# HP TÃ¼rkiye Garantili              1
# Monster TÃ¼rkiye Garantili         1
# Name: count, dtype: int64

# %%
df["Garanti_Tipi"] = enc.fit_transform(df['Garanti_Tipi'])

# %%
df["Garanti_Tipi"].value_counts()
# Out:
# Garanti_Tipi
# 18    245
# 4      57
# 12     52
# 6      35
# 9      32
# 0      30
# 2      28
# 16     23
# 22     23
# 14     22
# 17     11
# 7       9
# 10      7
# 23      6
# 3       5
# 21      4
# 1       2
# 11      2
# 19      1
# 5       1
# 13      1
# 20      1
# 8       1
# 15      1
# Name: count, dtype: int64

# %%
df["Ram"].value_counts()
# Out:
# Ram
# 16.0     323
# 8.0      144
# 32.0      68
# 4.0       28
# 64.0      16
# 128.0      7
# 18.0       3
# 36.0       3
# 12.0       2
# 48.0       2
# 24.0       2
# 1.0        1
# Name: count, dtype: int64

# %%
df["Ram"].value_counts()
# Out:
# Ram
# 16.0     323
# 8.0      144
# 32.0      68
# 4.0       28
# 64.0      16
# 128.0      7
# 18.0       3
# 36.0       3
# 12.0       2
# 48.0       2
# 24.0       2
# 1.0        1
# Name: count, dtype: int64

# %%
df["SSD_Kapasitesi"].value_counts()
# Out:
# SSD_Kapasitesi
# 512.0     279
# 1000.0    142
# 256.0     104
# 128.0      19
# 500.0      19
# 2000.0     13
# 240.0       7
# 4000.0      5
# 120.0       5
# 32.0        2
# 480.0       2
# 8.0         1
# 64.0        1
# Name: count, dtype: int64

# %%
df["SSD_Kapasitesi"].value_counts()
# Out:
# SSD_Kapasitesi
# 512.0     279
# 1000.0    142
# 256.0     104
# 128.0      19
# 500.0      19
# 2000.0     13
# 240.0       7
# 4000.0      5
# 120.0       5
# 32.0        2
# 480.0       2
# 8.0         1
# 64.0        1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Ekran_Karti  Ekran_Karti_Hafizasi  Ekran_Karti_Tipi  Garanti_Suresi  \
# 0           14                     7                 1             2.0
# 1            2                     7                 1             2.0
# 3            7                     4                 2             2.0
# 4           14                     7                 1             2.0
# 5            2                     7                 1             2.0
#
#    Garanti_Tipi   Ram  SSD_Kapasitesi   Islemci_Tipi  Islemci_Cekirdek_Sayisi  \
# 0            18   8.0           256.0  Intel Core i5                      4.0
# 1            12  16.0           512.0    AMD Ryzen 7                      8.0
# 3            18  32.0           256.0     Intel Xeon                      6.0
# 4            12   4.0           512.0  Intel Celeron                      4.0
# 5            18   8.0           256.0     AMD Athlon                      2.0
#
#     Fiyat
# 0  10.499
# 1  13.999
# 3  11.999
# 4   6.579
# 5   8.199

# %%
df["Islemci_Tipi"].value_counts()
# Out:
# Islemci_Tipi
# Intel Core i5       267
# Intel Core i7       104
# AMD Ryzen 5          47
# AMD Ryzen 7          41
# Intel Core i3        30
# Intel Core i9        26
# Intel Celeron        25
# M3                   10
# Intel Xeon            9
# Apple M1              7
# M2                    6
# Apple M2              5
# AMD Ryzen 3           5
# AMD Athlon            4
# MediaTek P60T         3
# AMD Ryzen 9           2
# Apple M1 Pro          1
# Intel Atom            1
# AMD E                 1
# Intel Core M          1
# AMD A6                1
# Ryzen Z1 Extreme      1
# Apple M2 Pro          1
# AMD                   1
# Name: count, dtype: int64

# %%
df["Islemci_Tipi"] = enc.fit_transform(df['Islemci_Tipi'])

# %%
df["Islemci_Tipi"].value_counts()
# Out:
# Islemci_Tipi
# 16    267
# 17    104
# 5      47
# 6      41
# 15     30
# 18     26
# 13     25
# 21     10
# 19      9
# 8       7
# 20      6
# 10      5
# 4       5
# 2       4
# 22      3
# 7       2
# 9       1
# 12      1
# 3       1
# 14      1
# 1       1
# 23      1
# 11      1
# 0       1
# Name: count, dtype: int64

# %%
df["Islemci_Cekirdek_Sayisi"].value_counts()
# Out:
# Islemci_Cekirdek_Sayisi
# 8.0     208
# 4.0     101
# 6.0      74
# 10.0     57
# 12.0     40
# 14.0     37
# 2.0      36
# 24.0     21
# 16.0     16
# 1.0       5
# 20.0      3
# 18.0      1
# Name: count, dtype: int64

# %%
df["Islemci_Cekirdek_Sayisi"].value_counts()
# Out:
# Islemci_Cekirdek_Sayisi
# 8.0     208
# 4.0     101
# 6.0      74
# 10.0     57
# 12.0     40
# 14.0     37
# 2.0      36
# 24.0     21
# 16.0     16
# 1.0       5
# 20.0      3
# 18.0      1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Ekran_Karti  Ekran_Karti_Hafizasi  Ekran_Karti_Tipi  Garanti_Suresi  \
# 0           14                     7                 1             2.0
# 1            2                     7                 1             2.0
# 3            7                     4                 2             2.0
# 4           14                     7                 1             2.0
# 5            2                     7                 1             2.0
#
#    Garanti_Tipi   Ram  SSD_Kapasitesi  Islemci_Tipi  Islemci_Cekirdek_Sayisi  \
# 0            18   8.0           256.0            16                      4.0
# 1            12  16.0           512.0             6                      8.0
# 3            18  32.0           256.0            19                      6.0
# 4            12   4.0           512.0            13                      4.0
# 5            18   8.0           256.0             2                      2.0
#
#     Fiyat
# 0  10.499
# 1  13.999
# 3  11.999
# 4   6.579
# 5   8.199

# %%
df.tail()
# Out:
#      Ekran_Karti  Ekran_Karti_Hafizasi  Ekran_Karti_Tipi  Garanti_Suresi  \
# 595           14                     7                 1             2.0
# 596            6                     7                 2             2.0
# 597           49                     7                 2             2.0
# 598           50                     1                 2             2.0
# 599           14                     7                 1             2.0
#
#      Garanti_Tipi   Ram  SSD_Kapasitesi  Islemci_Tipi  \
# 595            18   8.0           256.0             5
# 596            18  16.0           256.0            16
# 597            18  32.0           512.0            16
# 598            21  16.0          1000.0            18
# 599             2  64.0          1000.0            20
#
#      Islemci_Cekirdek_Sayisi     Fiyat
# 595                      4.0   10.4990
# 596                      4.0    7.0990
# 597                     10.0   43.6159
# ...

# %%
df.describe()
# Out:
#        Ekran_Karti  Ekran_Karti_Hafizasi  Ekran_Karti_Tipi  Garanti_Suresi  \
# count   599.000000            599.000000        599.000000      599.000000
# mean     32.390651              5.796327          1.699499        2.015025
# std      16.164010              1.512021          0.654173        0.121754
# min       0.000000              0.000000          0.000000        2.000000
# 25%      18.000000              5.000000          1.000000        2.000000
# 50%      40.000000              6.000000          2.000000        2.000000
# 75%      47.000000              7.000000          2.000000        2.000000
# max      58.000000              7.000000          5.000000        3.000000
#
#        Garanti_Tipi         Ram  SSD_Kapasitesi  Islemci_Tipi  \
# count    599.000000  599.000000      599.000000    599.000000
# mean      12.786311   18.128548      622.337229     14.277129
# std        6.585767   16.164865      462.584263      4.497118
# ...

# %%
df.shape
# Out:
# (599, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 599 entries, 0 to 599
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ekran_Karti              599 non-null    int32
#  1   Ekran_Karti_Hafizasi     599 non-null    int32
#  2   Ekran_Karti_Tipi         599 non-null    int64
#  3   Garanti_Suresi           599 non-null    float64
#  4   Garanti_Tipi             599 non-null    int32
#  5   Ram                      599 non-null    float64
#  6   SSD_Kapasitesi           599 non-null    float64
#  7   Islemci_Tipi             599 non-null    int32
#  8   Islemci_Cekirdek_Sayisi  599 non-null    float64
#  9   Fiyat                    599 non-null    float64
# dtypes: float64(5), int32(4), int64(1)
# memory usage: 42.1 KB

# %%
from sklearn.model_selection import learning_curve, RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_classif, chi2
#from sklearn.preprocessing import MinMaxScaler, StandartScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
from sklearn.model_selection import train_test_split
X=df.drop(["Fiyat"],axis=1)
y=df["Fiyat"]
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0 )

print("x_train :", x_train.shape)
print("x_test :", x_train.shape)
print("y_train :", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# x_train : (479, 9)
# x_test : (479, 9)
# y_train : (479,)
# y_test : (120,)

# %%
 y_predict
# Out:
# array([  9.61703478,  22.89268187,  21.81909095,  20.79343138,
#         33.73363912,  16.27665515,  14.47299644, 107.4130914 ,
#        123.75760163,  51.7594417 ,  27.03965344,  35.85596724,
#         39.0990724 ,  63.83530228,  61.26938812,  22.76595232,
#          4.66196502,  33.81607475,  28.82207753,  31.28609289,
#         10.39267049,  22.76595232,  24.77749116,  19.60284516,
#         35.21187147,  18.30835188,  24.69994172,   6.5438557 ,
#         20.84958209,  33.36269159,  58.73739471,  39.46641287,
#        -72.768991  ,  31.65824281,  25.00254461,  35.71133163,
#         62.23266296,  20.46836183,  30.30802377,  19.82626511,
#         18.83578275,  16.66673091,  49.32432649,  22.76595232,
#         13.71605147,  15.60602792,  29.17625515,  35.23654417,
#         32.92822738,  24.66689559, -61.36223437,  39.89410961,
#         16.29680982,  22.76595232,  35.11633097,  20.63720399,
#         32.81552411,  32.65568539,  36.71018308,  26.03111986,
# ...

# %%
print("mean absolute error: ",mean_absolute_error(y_test, y_predict))
print("root mean squared error: ",np.sqrt(mean_squared_error(y_test, y_predict)))
print("Coefficient of Determination R^2 ",r2_score(y_test, y_predict)) #önemli olan r2 scoredur
# Out:
# mean absolute error:  12.340924274742063
# root mean squared error:  18.91940089744063
# Coefficient of Determination R^2  0.4677592352065969

# %%
#Grafikte görelim 
fig = plt.figure(figsize=(12,6))
result = pd.DataFrame({"Predicted": y_predict, "Actual": y_test})
result = result.reset_index()
result = result.drop(["index"], axis=1)
plt.plot(result[:100])
plt.legend(["Actual","Predicted"])
plt.title("ACTUAL - PREDICTED  (Linear Regression)")
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
y_predict_dt = dt.predict(x_test)
print("mean absolute error: ",mean_absolute_error(y_test, y_predict_dt))
print("root mean squared error: ",np.sqrt(mean_squared_error(y_test, y_predict_dt)))
print("Coefficient of Determination R^2 ",r2_score(y_test, y_predict_dt)) #önemli olan r2 scoredur
# Out:
# mean absolute error:  7.873758694444445
# root mean squared error:  17.110805736497174
# Coefficient of Determination R^2  0.5646542630889545

# %%
#Grafikte görelim 
fig = plt.figure(figsize=(12,6))
result = pd.DataFrame({"Predicted": y_predict_dt, "Actual": y_test})
result = result.reset_index()
result = result.drop(["index"], axis=1)
plt.plot(result[:100])
plt.legend(["Actual","Predicted"])
plt.title("ACTUAL - PREDICTED  (Decision Tree)")
plt.show()

# %%
lasso = Lasso(alpha=0.001)
lasso.fit(x_train, y_train)
y_predict_lasso = lasso.predict(x_test)
print("mean absolute error: ",mean_absolute_error(y_test, y_predict_lasso))
print("root mean squared error: ",np.sqrt(mean_squared_error(y_test, y_predict_lasso)))
print("Coefficient of Determination R^2 ",r2_score(y_test, y_predict_lasso)) #önemli olan r2 scoredur
# Out:
# mean absolute error:  12.33865170291538
# root mean squared error:  18.91680844609448
# Coefficient of Determination R^2  0.467905086944692

# %%
fig = plt.figure(figsize=(12,6))
result = pd.DataFrame({"Predicted": y_predict_lasso, "Actual": y_test})
result = result.reset_index()
result = result.drop(["index"], axis=1)
plt.plot(result[:100])
plt.legend(["Actual","Predicted"])
plt.title("ACTUAL - PREDICTED (Lasso)")
plt.show()

# %%
from sklearn.svm import SVR
svm_regressor = SVR()
svm_regressor.fit(x_train, y_train)
y_predict_svm = svm_regressor.predict(x_test)
print("mean absolute error: ",mean_absolute_error(y_test, y_predict_svm))
print("root mean squared error: ",np.sqrt(mean_squared_error(y_test, y_predict_svm)))
print("Coefficient of Determination R^2 ",r2_score(y_test, y_predict_svm)) #önemli olan r2 scoredur
# Out:
# mean absolute error:  12.093380163369348
# root mean squared error:  23.254731610953527
# Coefficient of Determination R^2  0.19588893582920763

# %%
fig = plt.figure(figsize=(12,6))
result = pd.DataFrame({"Predicted": y_predict_svm, "Actual": y_test})
result = result.reset_index()
result = result.drop(["index"], axis=1)
plt.plot(result[:100])
plt.legend(["Actual","Predicted"])
plt.title("ACTUAL - PREDICTED (Support Vector Machine Regressor)")
plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor
gradient_boosting = GradientBoostingRegressor()
gradient_boosting.fit(x_train, y_train)
y_predict_boosting = gradient_boosting.predict(x_test)

print("mean absolute error: ",mean_absolute_error(y_test, y_predict_boosting))
print("root mean squared error: ",np.sqrt(mean_squared_error(y_test, y_predict_boosting)))
print("Coefficient of Determination R^2 ",r2_score(y_test, y_predict_boosting)) #önemli olan r2 scoredur
# Out:
# mean absolute error:  6.002424295921795
# root mean squared error:  10.00047109501174
# Coefficient of Determination R^2  0.851292013776727

# %%
fig = plt.figure(figsize=(12,6))
result = pd.DataFrame({"Predicted": y_predict_boosting, "Actual": y_test})
result = result.reset_index()
result = result.drop(["index"], axis=1)
plt.plot(result[:100])
plt.legend(["Actual","Predicted"])
plt.title("ACTUAL - PREDICTED (Gradient Boosting )")
plt.show()

# %%
from sklearn.neighbors import KNeighborsRegressor


knn_regressor = KNeighborsRegressor()
knn_regressor.fit(x_train, y_train)
y_predict_knn = knn_regressor.predict(x_test)

print("mean absolute error: ",mean_absolute_error(y_test, y_predict_knn))
print("root mean squared error: ",np.sqrt(mean_squared_error(y_test, y_predict_knn)))
print("Coefficient of Determination R^2 ",r2_score(y_test, y_predict_knn)) #önemli olan r2 scoredur
# Out:
# mean absolute error:  9.1014484
# root mean squared error:  17.73634163609037
# Coefficient of Determination R^2  0.5322417395101464

# %%
fig = plt.figure(figsize=(12,6))
result = pd.DataFrame({"Predicted": y_predict_knn, "Actual": y_test})
result = result.reset_index()
result = result.drop(["index"], axis=1)
plt.plot(result[:100])
plt.legend(["Actual","Predicted"])
plt.title("ACTUAL - PREDICTED (KNeighbors )")
plt.show()

# %%
from sklearn.linear_model import ElasticNet
elasticnet = ElasticNet(alpha=0.1, l1_ratio=0.5) 
elasticnet.fit(x_train, y_train)
y_predict_elasticnet = elasticnet.predict(x_test)
print("mean absolute error: ",mean_absolute_error(y_test, y_predict_elasticnet))
print("root mean squared error: ",np.sqrt(mean_squared_error(y_test, y_predict_elasticnet)))
print("Coefficient of Determination R^2 ",r2_score(y_test, y_predict_elasticnet)) #önemli olan r2 scoredur
# Out:
# mean absolute error:  11.978706220285464
# root mean squared error:  18.072175838284313
# Coefficient of Determination R^2  0.5143602110054057

# %%
fig = plt.figure(figsize=(12,6))
result = pd.DataFrame({"Predicted": y_predict_elasticnet, "Actual": y_test})
result = result.reset_index()
result = result.drop(["index"], axis=1)
plt.plot(result[:100])
plt.legend(["Actual","Predicted"])
plt.title("ACTUAL - PREDICTED (Elasticnet)")
plt.show()

# %%
from sklearn.linear_model import SGDRegressor
gradient_descent = SGDRegressor()
gradient_descent.fit(x_train, y_train)
y_predict_gradient = gradient_descent.predict(x_test)
print("mean absolute error: ",mean_absolute_error(y_test, y_predict_gradient))
print("root mean squared error: ",np.sqrt(mean_squared_error(y_test, y_predict_gradient)))
print("Coefficient of Determination R^2 ",r2_score(y_test, y_predict_gradient)) #önemli olan r2 scoredur

# %%
df.to_csv("bilgisayar_data_islenmis_son.csv",encoding='utf-8-sig',index=False)
