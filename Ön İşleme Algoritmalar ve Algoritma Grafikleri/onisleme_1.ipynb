# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("bilgisayar_data_islenmemis2.csv")
df=pd.DataFrame()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 69 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ArttÄ±rÄ±labilir Azami Bellek    13 non-null     object
#  1   Arttırılabilir Azami Bellek      115 non-null    object
#  2   BaÄŸlantÄ±lar                    20 non-null     object
#  3   Bağlantılar                      417 non-null    object
#  4   Bağlantılar (İkincil)            9 non-null      object
#  5   Beden                            19 non-null     object
#  6   Cihaz AÄŸÄ±rlÄ±ÄŸÄ±              23 non-null     object
#  7   Cihaz Ağırlığı                   473 non-null    object
#  8   Dokunmatik Ekran                 438 non-null    object
#  9   Ekran Boyutu                     489 non-null    object
#  10  Ekran KartÄ±                     25 non-null     object
#  11  Ekran KartÄ± Bellek Tipi         25 non-null     object
# ...

# %%
data = data.drop(['ArttÄ±rÄ±labilir Azami Bellek','BaÄŸlantÄ±lar','Bağlantılar (İkincil)','Cihaz AÄŸÄ±rlÄ±ÄŸÄ±','Ekran KartÄ±','Ekran KartÄ± Bellek Tipi','Ekran KartÄ± HafÄ±zasÄ±','Ekran KartÄ± Tipi','Ekran Yenileme HÄ±zÄ±','Ekran Özelliği','Garanti SÃ¼resi','Görüntü Kalitesi','HDMI','Hard Disk Kapasitesi','Kapasite','Klavye','KullanÄ±m AmacÄ±','Maksimum Ä°ÅŸlemci HÄ±zÄ± (GHz)','Kullanım Amacı','Maksimum İşlemci Hızı (GHz)','Okula DÃ¶nÃ¼ÅŸ','Okula Dönüş','Optik SÃ¼rÃ¼cÃ¼ Tipi','Optik Sürücü Tipi','Panel Tipi','Power Supply','Ram (Sistem BelleÄŸi)','Ram (Sistem BelleÄŸi) Tipi','Ram (Sistem Belleği) Tipi','Renk','SSD Teknolojisi','Soket Tipi','Temel Ä°ÅŸlemci HÄ±zÄ± (GHz)','Temel İşlemci Hızı (GHz)','Ã‡Ã¶zÃ¼nÃ¼rlÃ¼k','Ã‡Ã¶zÃ¼nÃ¼rlÃ¼k StandartÄ±','Ä°ÅŸlemci FrekansÄ±','Ä°ÅŸlemci Modeli','Ä°ÅŸlemci Nesli','Ä°ÅŸlemci Tipi','Ä°ÅŸlemci Ã‡ekirdek SayÄ±sÄ±','Ä°ÅŸletim Sistemi','ÅžarjlÄ± KullanÄ±m SÃ¼resi','Çözünürlük','Çözünürlük Standartı','İşlemci Frekansı','Şarjlı Kullanım Süresi'],axis=1)

# %%
data = data.drop(['Arttırılabilir Azami Bellek','Bağlantılar','Beden','Cihaz Ağırlığı','Dokunmatik Ekran','Ekran Boyutu'],axis=1)

# %%
data = data.drop(['İşlemci Nesli','İşlemci Modeli','İşletim Sistemi','Ekran Yenileme Hızı'],axis=1)

# %%
data = data.drop(['Ekran Kartı Bellek Tipi','url'],axis=1)

# %%
plt.figure(figsize=(12,12))
plt.subplot(3,1,1)
sns.countplot(x='İşlemci Tipi',data=data,order=data['İşlemci Tipi'].value_counts().index)
plt.xticks(rotation=70)
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ekran Kartı              526 non-null    object
#  1   Ekran Kartı Hafızası     489 non-null    object
#  2   Ekran Kartı Tipi         522 non-null    object
#  3   Garanti Süresi           509 non-null    object
#  4   Garanti Tipi             551 non-null    object
#  5   Ram (Sistem Belleği)     526 non-null    object
#  6   SSD Kapasitesi           551 non-null    object
#  7   İşlemci Tipi             526 non-null    object
#  8   İşlemci Çekirdek Sayısı  521 non-null    object
#  9   price                    600 non-null    object
# dtypes: object(10)
# memory usage: 47.0+ KB

# %%
data['price'] = data['price'].str.replace('TL', '')

# %%
data["price"]
# Out:
# 0         10.499
# 1         13.999
# 2          6.939
# 3         11.999
# 4          6.579
#           ...
# 595       10.499
# 596        7.099
# 597    43.615,90
# 598       94.999
# 599      129.999
# Name: price, Length: 600, dtype: object

# %%
data['price'] = data['price'].str.replace(',', '')

# %%
data["price"]
# Out:
# 0        10.499
# 1        13.999
# 2         6.939
# 3        11.999
# 4         6.579
#          ...
# 595      10.499
# 596       7.099
# 597    43.61590
# 598      94.999
# 599     129.999
# Name: price, Length: 600, dtype: object

# %%
data['price'] = data['price'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ekran Kartı              526 non-null    object
#  1   Ekran Kartı Hafızası     489 non-null    object
#  2   Ekran Kartı Tipi         522 non-null    object
#  3   Garanti Süresi           509 non-null    object
#  4   Garanti Tipi             551 non-null    object
#  5   Ram (Sistem Belleği)     526 non-null    object
#  6   SSD Kapasitesi           551 non-null    object
#  7   İşlemci Tipi             526 non-null    object
#  8   İşlemci Çekirdek Sayısı  521 non-null    object
#  9   price                    600 non-null    float64
# dtypes: float64(1), object(9)
# memory usage: 47.0+ KB

# %%
data.tail()
# Out:
#                     Ekran Kartı Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240                  NaN           Harici
# 597     Nvidia GeForce RTX 4070                  NaN           Harici
# 598  Nvidia GeForce RTX 4070 Ti                12 GB           Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#     Garanti Süresi                 Garanti Tipi Ram (Sistem Belleği)  \
# 595          2 Yıl  Resmi Distribütör Garantili                 8 GB
# 596          2 Yıl  Resmi Distribütör Garantili                16 GB
# 597          2 Yıl  Resmi Distribütör Garantili                32 GB
# 598          2 Yıl     Zeiron Türkiye Garantili                16 GB
# 599          2 Yıl      Apple Türkiye Garantili                64 GB
#
#     SSD Kapasitesi   İşlemci Tipi İşlemci Çekirdek Sayısı     price
# ...

# %%
data['Garanti Süresi'] = data['Garanti Süresi'].str.replace('Yıl', '')

# %%
data.tail()
# Out:
#                     Ekran Kartı Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240                  NaN           Harici
# 597     Nvidia GeForce RTX 4070                  NaN           Harici
# 598  Nvidia GeForce RTX 4070 Ti                12 GB           Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#     Garanti Süresi                 Garanti Tipi Ram (Sistem Belleği)  \
# 595             2   Resmi Distribütör Garantili                 8 GB
# 596             2   Resmi Distribütör Garantili                16 GB
# 597             2   Resmi Distribütör Garantili                32 GB
# 598             2      Zeiron Türkiye Garantili                16 GB
# 599             2       Apple Türkiye Garantili                64 GB
#
#     SSD Kapasitesi   İşlemci Tipi İşlemci Çekirdek Sayısı     price
# ...

# %%
data['Ram (Sistem Belleği)'] = data['Ram (Sistem Belleği)'].str.replace('GB', '')

# %%
data['SSD Kapasitesi'] = data['SSD Kapasitesi'].replace('1 TB', '1000 GB')

# %%
data.tail()
# Out:
#                     Ekran Kartı Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240                  NaN           Harici
# 597     Nvidia GeForce RTX 4070                  NaN           Harici
# 598  Nvidia GeForce RTX 4070 Ti                12 GB           Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#     Garanti Süresi                 Garanti Tipi Ram (Sistem Belleği)  \
# 595             2   Resmi Distribütör Garantili                   8
# 596             2   Resmi Distribütör Garantili                  16
# 597             2   Resmi Distribütör Garantili                  32
# 598             2      Zeiron Türkiye Garantili                  16
# 599             2       Apple Türkiye Garantili                  64
#
#     SSD Kapasitesi   İşlemci Tipi İşlemci Çekirdek Sayısı     price
# ...

# %%
data['SSD Kapasitesi'] = data['SSD Kapasitesi'].str.replace('GB', '')

# %%
data.tail()
# Out:
#                     Ekran Kartı Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240                  NaN           Harici
# 597     Nvidia GeForce RTX 4070                  NaN           Harici
# 598  Nvidia GeForce RTX 4070 Ti                12 GB           Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#     Garanti Süresi                 Garanti Tipi Ram (Sistem Belleği)  \
# 595             2   Resmi Distribütör Garantili                   8
# 596             2   Resmi Distribütör Garantili                  16
# 597             2   Resmi Distribütör Garantili                  32
# 598             2      Zeiron Türkiye Garantili                  16
# 599             2       Apple Türkiye Garantili                  64
#
#     SSD Kapasitesi   İşlemci Tipi İşlemci Çekirdek Sayısı     price
# ...

# %%
data['Ekran Kartı Hafızası'] = data['Ekran Kartı Hafızası'].str.replace('GB', '')

# %%
data.tail()
# Out:
#                     Ekran Kartı Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240                  NaN           Harici
# 597     Nvidia GeForce RTX 4070                  NaN           Harici
# 598  Nvidia GeForce RTX 4070 Ti                  12            Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#     Garanti Süresi                 Garanti Tipi Ram (Sistem Belleği)  \
# 595             2   Resmi Distribütör Garantili                   8
# 596             2   Resmi Distribütör Garantili                  16
# 597             2   Resmi Distribütör Garantili                  32
# 598             2      Zeiron Türkiye Garantili                  16
# 599             2       Apple Türkiye Garantili                  64
#
#     SSD Kapasitesi   İşlemci Tipi İşlemci Çekirdek Sayısı     price
# ...

# %%
data['SSD Kapasitesi'] = data['SSD Kapasitesi'].str.replace('SSD Yok', '')

# %%
data['SSD Kapasitesi'].fillna(np.nan, inplace=True)

# %%
data['Garanti Süresi'] = data['Garanti Süresi'].astype(float)
data['Ram (Sistem Belleği)'] = data['Ram (Sistem Belleği)'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ekran Kartı              526 non-null    object
#  1   Ekran Kartı Hafızası     489 non-null    object
#  2   Ekran Kartı Tipi         522 non-null    object
#  3   Garanti Süresi           509 non-null    float64
#  4   Garanti Tipi             551 non-null    object
#  5   Ram (Sistem Belleği)     526 non-null    float64
#  6   SSD Kapasitesi           551 non-null    object
#  7   İşlemci Tipi             526 non-null    object
#  8   İşlemci Çekirdek Sayısı  521 non-null    object
#  9   price                    600 non-null    float64
# dtypes: float64(3), object(7)
# memory usage: 47.0+ KB

# %%
data.replace('', np.nan, inplace=True)

# %%
data['SSD Kapasitesi'] = data['SSD Kapasitesi'].replace('2 TB', '2000 GB')
data['SSD Kapasitesi'] = data['SSD Kapasitesi'].replace('4 TB', '4000 GB')
data['SSD Kapasitesi'] = data['SSD Kapasitesi'].str.replace('GB', '')
data['SSD Kapasitesi'] = data['SSD Kapasitesi'].str.replace('Yok', '')
data.replace('', np.nan, inplace=True)

# %%
data['SSD Kapasitesi'] = data['SSD Kapasitesi'].astype(float)

# %%
data['İşlemci Çekirdek Sayısı'] = data['İşlemci Çekirdek Sayısı'].str.replace('Belirtilmemiş', '')
data.replace('', np.nan, inplace=True)

# %%
data['İşlemci Çekirdek Sayısı'] = data['İşlemci Çekirdek Sayısı'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ekran Kartı              526 non-null    object
#  1   Ekran Kartı Hafızası     489 non-null    object
#  2   Ekran Kartı Tipi         522 non-null    object
#  3   Garanti Süresi           509 non-null    float64
#  4   Garanti Tipi             551 non-null    object
#  5   Ram (Sistem Belleği)     526 non-null    float64
#  6   SSD Kapasitesi           539 non-null    float64
#  7   İşlemci Tipi             526 non-null    object
#  8   İşlemci Çekirdek Sayısı  507 non-null    float64
#  9   price                    600 non-null    float64
# dtypes: float64(5), object(5)
# memory usage: 47.0+ KB

# %%
data.tail()
# Out:
#                     Ekran Kartı Ekran Kartı Hafızası Ekran Kartı Tipi  \
# 595          Dahili Ekran Kartı           Paylaşımlı           Dahili
# 596           AMD Radeon R7 240                  NaN           Harici
# 597     Nvidia GeForce RTX 4070                  NaN           Harici
# 598  Nvidia GeForce RTX 4070 Ti                  12            Harici
# 599          Dahili Ekran Kartı           Paylaşımlı           Dahili
#
#      Garanti Süresi                 Garanti Tipi  Ram (Sistem Belleği)  \
# 595             2.0  Resmi Distribütör Garantili                   8.0
# 596             2.0  Resmi Distribütör Garantili                  16.0
# 597             2.0  Resmi Distribütör Garantili                  32.0
# 598             2.0     Zeiron Türkiye Garantili                  16.0
# 599             2.0      Apple Türkiye Garantili                  64.0
#
#      SSD Kapasitesi   İşlemci Tipi  İşlemci Çekirdek Sayısı     price
# ...

# %%
df=pd.DataFrame()
data.replace(',,,,,,,,,','', inplace=True)

# %%
data.to_csv("bilgisayar_data_islenmis3.csv",encoding='utf-8-sig',index=False)
